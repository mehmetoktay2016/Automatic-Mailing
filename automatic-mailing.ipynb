# %%
import smtplib

content = "Hello, we miss you so much. We have listed new products for you."
mail = smtplib.SMTP("smtp.gmail.com",587)
mail.ehlo()
mail.starttls()
mail.login("your mail account" , "your password")
mail.sendmail("your mail account(gmail)","mail destination account",content)
